# %% [raw]
# Task 1: Exploring and Visualizing a Simple Dataset
# Objective:
#  Understand how to read, summarize, and visualize a dataset.
# Dataset:
#  Iris Dataset (CSV format, available through seaborn or other open sources) Instructions:
# ●	Load the dataset using the pandas library.
#
# ●	Display dataset structure using .shape, .columns, and .head().
#
# ●	Create basic visualizations:
#
# ○ Scatter plot to analyze relationships between variables.
#
# ○ Histogram to examine data distribution.
#
# ○ Box plot to detect outliers and spread of values.
#
# ●	Use matplotlib and seaborn for visualizations.
#
# Skills:
# ●	Data loading and inspection using pandas
#
# ●	Basic data summarization
#
# ●	Visualization using matplotlib and seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure()
sns.scatterplot(data=df, x='petal_length', y='petal_width', hue='species')
plt.title('Petal Length vs Petal Width')
plt.show()

# %%
plt.figure()
sns.histplot(df['sepal_length'], kde=True)
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.boxplot(data=df, x='species', y='sepal_width')
plt.title('Sepal Width by Species')
plt.show()

# %% [raw]
# Conclusion
# Exploring the Iris dataset demonstrates how fundamental data inspection and visualization transform raw numbers into clear biological insights. By utilizing Pandas to verify data structure and Seaborn to map relationships, we can visually confirm that physical measurements—specifically petal length and width—serve as distinct markers for identifying different species. Scatter plots reveal clear clustering, while histograms and box plots provide a transparent view of data distribution and potential outliers. Ultimately, this process establishes a vital baseline of understanding, ensuring that the data is clean and the underlying patterns are well-understood before any further analysis.
